# %% [markdown]
# <a href="https://colab.research.google.com/github/Onkargaikwad/credit-card/blob/main/text_summary_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load Pkgs
import spacy 
# Text Preprocessing Pkg
from spacy.lang.en.stop_words import STOP_WORDS
from string import punctuation
# Build a List of Stopwords
stopwords = list(STOP_WORDS)

# %%
document1='''The two men sat across from each other in soft leather chairs. Flames from the fireplace before them licked upward and shadows danced on walls and ceiling. The corners were in complete darkness.

"I say, George, this wine is exceedingly good," one of the men poured rich red liquid from a large decanter into his goblet.

"Yes, Henry, it's quite good. Much better than brandy," answered George, swallowing hard and rolling his head.

"Yes, yes," said Henry, sighing deeply, his lips and chin stained from the beverage. "Yes. Yes. Nothing like good wine. Nothing like it."

"As I was saying," smiled George.

"Oh yes," Henry nodded, setting his goblet on the table and leaning forward in his seat. "Do continue with your story. You were telling me about how you met the Devil last week, and had an interesting chat with him." He winked mischievously.

George shook his head vigorously. "And I most certainly did. Yes. Met the Devil and had an enjoyable chat. He's a splendid chap, you know. Not at all like those pictures you see of him. No horns or red monkey outfit. He dresses most conservatively; wears a black suit. And he has nice gray hair." George patted his head. "Nice gray hair."

Henry poured himself another cup of wine and sipped it slowly. "But what did you talk about? I mean you have nothing in common at all."

"Oh no?" George shrugged. "But we do. We have much in common. I admire the Devil and told him so. And he said that he would be glad to have me come and work for him."

"Work for him?"

"Yes. He wants me to go with him to his headquarters."

"But his headquarters are in ... a ... well you know."

"I know, but I still want to go. He said he would make me a demon or a ghoul or something."

"Horrid, don't you think?"

"No, not at all." George gulped down the last of his wine. "Quite pleasant if I may say so. Quite a change from the market and speculation and," he snorted loudly, "those damn commodities that I lost so heavily on yesterday. No, I think I'd enjoy seeing things as a demon or a ghoul or something."

"What do you see?"

"Oh you know. Graveyards, coffins and corpses...."

Henry laughed. "Oh, that's amusing. Most amusing."

George smiled tightly. "And you see the dead in Hell, the fire and brimstone, and you hear their cries of anguish and it's quite pleasant."

"Then why don't you go with the Devil and be done with it?"

"But I am going to go, Henry."

"Then go!"

"But I must do something first. It's a sort of qualification."

"Yes?"

"I must kill someone."

"But that's most naughty, old boy, isn't it?"

"Not when you have a good reason."

Henry held up the decanter and looked at the small amount of wine that was left. He shook his head sadly. "But who's going to be your victim?"

"You," answered George.

"Me?" said Henry, smiling.

"Yes, you."

"Are you mad?"

"No."

Henry stopped smiling and his face grew a trifle pale. He suddenly had the sickening feeling that George wasn't kidding him any more. "But why me?"

George pulled a small revolver from his breast pocket. "I have it from what I believe to be a thoroughly reliable source that while I was out of town last week you were out with my wife."'''

# %%
nlp = spacy.load('en')
# Build an NLP Object
docx = nlp(document1)
# Tokenization of Text
mytokens = [token.text for token in docx]

# %%
word_frequencies = {}
for word in docx:
    if word.text not in stopwords:
            if word.text not in word_frequencies.keys():
                word_frequencies[word.text] = 1
            else:
                word_frequencies[word.text] += 1

# %%
word_frequencies
# Out:
# {'\n\n': 34,
#  '!': 1,
#  '"': 80,
#  ',': 32,
#  '.': 65,
#  '...': 2,
#  '....': 1,
#  ';': 1,
#  '?': 12,
#  'And': 4,
#  'Are': 1,
#  'As': 1,
#  'But': 8,
#  'Devil': 4,
#  'Do': 1,
#  'Flames': 1,
#  'George': 11,
#  'Graveyards': 1,
#  'He': 7,
#  'Hell': 1,
#  'Henry': 9,
#  'Horrid': 1,
#  'I': 17,
#  'It': 1,
#  'Me': 1,
#  'Met': 1,
#  'Most': 1,
#  'Much': 1,
#  'Nice': 1,
#  'No': 4,
#  'Not': 2,
#  'Nothing': 2,
#  'Oh': 4,
#  'Quite': 2,
#  'The': 2,
#  'Then': 2,
#  'We': 1,
#  'What': 1,
#  'Work': 1,
#  'Yes': 8,
#  'You': 2,
#  'admire': 1,
#  'amusing': 2,
#  'anguish': 1,
#  'answered': 2,
#  'believe': 1,
#  'better': 1,
#  'beverage': 1,
#  'black': 1,
#  'boy': 1,
#  'brandy': 1,
#  'breast': 1,
#  'brimstone': 1,
#  'ceiling': 1,
#  'certainly': 1,
#  'chairs': 1,
#  'change': 1,
#  'chap': 1,
#  'chat': 2,
#  'chin': 1,
#  'coffins': 1,
#  'come': 1,
#  'commodities': 1,
#  'common': 2,
#  'complete': 1,
#  'conservatively': 1,
#  'continue': 1,
#  'corners': 1,
#  'corpses': 1,
#  'cries': 1,
#  'cup': 1,
#  'damn': 1,
#  'danced': 1,
#  'darkness': 1,
#  'dead': 1,
#  'decanter': 2,
#  'deeply': 1,
#  'demon': 2,
#  'dresses': 1,
#  'enjoy': 1,
#  'enjoyable': 1,
#  'exceedingly': 1,
#  'face': 1,
#  'feeling': 1,
#  'fire': 1,
#  'fireplace': 1,
#  'forward': 1,
#  'ghoul': 2,
#  'glad': 1,
#  'goblet': 2,
#  'going': 2,
#  'good': 4,
#  'gray': 2,
#  'grew': 1,
#  'gulped': 1,
#  'hair': 2,
#  'hard': 1,
#  'head': 4,
#  'headquarters': 2,
#  'hear': 1,
#  'heavily': 1,
#  'held': 1,
#  'horns': 1,
#  'interesting': 1,
#  'kidding': 1,
#  'kill': 1,
#  'know': 4,
#  'large': 1,
#  'laughed': 1,
#  'leaning': 1,
#  'leather': 1,
#  'left': 1,
#  'licked': 1,
#  'like': 3,
#  'lips': 1,
#  'liquid': 1,
#  'looked': 1,
#  'lost': 1,
#  'loudly': 1,
#  'mad': 1,
#  'market': 1,
#  'mean': 1,
#  'men': 2,
#  'met': 1,
#  'mischievously': 1,
#  'monkey': 1,
#  'naughty': 1,
#  'nice': 1,
#  'nodded': 1,
#  'old': 1,
#  'outfit': 1,
#  'pale': 1,
#  'patted': 1,
#  'pictures': 1,
#  'pleasant': 2,
#  'pocket': 1,
#  'poured': 2,
#  'pulled': 1,
#  'qualification': 1,
#  'reason': 1,
#  'red': 2,
#  'reliable': 1,
#  'revolver': 1,
#  'rich': 1,
#  'rolling': 1,
#  'sadly': 1,
#  'said': 4,
#  'sat': 1,
#  'saying': 1,
#  'seat': 1,
#  'seeing': 1,
#  'setting': 1,
#  'shadows': 1,
#  'shook': 2,
#  'shrugged': 1,
#  'sickening': 1,
#  'sighing': 1,
#  'sipped': 1,
#  'slowly': 1,
#  'small': 2,
#  'smiled': 2,
#  'smiling': 2,
#  'snorted': 1,
#  'soft': 1,
#  'sort': 1,
#  'source': 1,
#  'speculation': 1,
#  'splendid': 1,
#  'stained': 1,
#  'stopped': 1,
#  'story': 1,
#  'suddenly': 1,
#  'suit': 1,
#  'swallowing': 1,
#  'table': 1,
#  'talk': 1,
#  'telling': 1,
#  'things': 1,
#  'think': 2,
#  'thoroughly': 1,
#  'tightly': 1,
#  'told': 1,
#  'town': 1,
#  'trifle': 1,
#  'upward': 1,
#  'victim': 1,
#  'vigorously': 1,
#  'walls': 1,
#  'want': 1,
#  'wants': 1,
#  'wears': 1,
#  'week': 2,
#  'wife': 1,
#  'wine': 5,
#  'winked': 1,
#  'work': 1,
#  'yes': 2,
#  'yesterday': 1}

# %%
# Maximum Word Frequency
maximum_frequency = max(word_frequencies.values())
for word in word_frequencies.keys():  
        word_frequencies[word] = (word_frequencies[word]/maximum_frequency)

# %%
# Frequency Table
word_frequencies
# Out:
# {'\n\n': 0.425,
#  '!': 0.0125,
#  '"': 1.0,
#  ',': 0.4,
#  '.': 0.8125,
#  '...': 0.025,
#  '....': 0.0125,
#  ';': 0.0125,
#  '?': 0.15,
#  'And': 0.05,
#  'Are': 0.0125,
#  'As': 0.0125,
#  'But': 0.1,
#  'Devil': 0.05,
#  'Do': 0.0125,
#  'Flames': 0.0125,
#  'George': 0.1375,
#  'Graveyards': 0.0125,
#  'He': 0.0875,
#  'Hell': 0.0125,
#  'Henry': 0.1125,
#  'Horrid': 0.0125,
#  'I': 0.2125,
#  'It': 0.0125,
#  'Me': 0.0125,
#  'Met': 0.0125,
#  'Most': 0.0125,
#  'Much': 0.0125,
#  'Nice': 0.0125,
#  'No': 0.05,
#  'Not': 0.025,
#  'Nothing': 0.025,
#  'Oh': 0.05,
#  'Quite': 0.025,
#  'The': 0.025,
#  'Then': 0.025,
#  'We': 0.0125,
#  'What': 0.0125,
#  'Work': 0.0125,
#  'Yes': 0.1,
#  'You': 0.025,
#  'admire': 0.0125,
#  'amusing': 0.025,
#  'anguish': 0.0125,
#  'answered': 0.025,
#  'believe': 0.0125,
#  'better': 0.0125,
#  'beverage': 0.0125,
#  'black': 0.0125,
#  'boy': 0.0125,
#  'brandy': 0.0125,
#  'breast': 0.0125,
#  'brimstone': 0.0125,
#  'ceiling': 0.0125,
#  'certainly': 0.0125,
#  'chairs': 0.0125,
#  'change': 0.0125,
#  'chap': 0.0125,
#  'chat': 0.025,
#  'chin': 0.0125,
#  'coffins': 0.0125,
#  'come': 0.0125,
#  'commodities': 0.0125,
#  'common': 0.025,
#  'complete': 0.0125,
#  'conservatively': 0.0125,
#  'continue': 0.0125,
#  'corners': 0.0125,
#  'corpses': 0.0125,
#  'cries': 0.0125,
#  'cup': 0.0125,
#  'damn': 0.0125,
#  'danced': 0.0125,
#  'darkness': 0.0125,
#  'dead': 0.0125,
#  'decanter': 0.025,
#  'deeply': 0.0125,
#  'demon': 0.025,
#  'dresses': 0.0125,
#  'enjoy': 0.0125,
#  'enjoyable': 0.0125,
#  'exceedingly': 0.0125,
#  'face': 0.0125,
#  'feeling': 0.0125,
#  'fire': 0.0125,
#  'fireplace': 0.0125,
#  'forward': 0.0125,
#  'ghoul': 0.025,
#  'glad': 0.0125,
#  'goblet': 0.025,
#  'going': 0.025,
#  'good': 0.05,
#  'gray': 0.025,
#  'grew': 0.0125,
#  'gulped': 0.0125,
#  'hair': 0.025,
#  'hard': 0.0125,
#  'head': 0.05,
#  'headquarters': 0.025,
#  'hear': 0.0125,
#  'heavily': 0.0125,
#  'held': 0.0125,
#  'horns': 0.0125,
#  'interesting': 0.0125,
#  'kidding': 0.0125,
#  'kill': 0.0125,
#  'know': 0.05,
#  'large': 0.0125,
#  'laughed': 0.0125,
#  'leaning': 0.0125,
#  'leather': 0.0125,
#  'left': 0.0125,
#  'licked': 0.0125,
#  'like': 0.0375,
#  'lips': 0.0125,
#  'liquid': 0.0125,
#  'looked': 0.0125,
#  'lost': 0.0125,
#  'loudly': 0.0125,
#  'mad': 0.0125,
#  'market': 0.0125,
#  'mean': 0.0125,
#  'men': 0.025,
#  'met': 0.0125,
#  'mischievously': 0.0125,
#  'monkey': 0.0125,
#  'naughty': 0.0125,
#  'nice': 0.0125,
#  'nodded': 0.0125,
#  'old': 0.0125,
#  'outfit': 0.0125,
#  'pale': 0.0125,
#  'patted': 0.0125,
#  'pictures': 0.0125,
#  'pleasant': 0.025,
#  'pocket': 0.0125,
#  'poured': 0.025,
#  'pulled': 0.0125,
#  'qualification': 0.0125,
#  'reason': 0.0125,
#  'red': 0.025,
#  'reliable': 0.0125,
#  'revolver': 0.0125,
#  'rich': 0.0125,
#  'rolling': 0.0125,
#  'sadly': 0.0125,
#  'said': 0.05,
#  'sat': 0.0125,
#  'saying': 0.0125,
#  'seat': 0.0125,
#  'seeing': 0.0125,
#  'setting': 0.0125,
#  'shadows': 0.0125,
#  'shook': 0.025,
#  'shrugged': 0.0125,
#  'sickening': 0.0125,
#  'sighing': 0.0125,
#  'sipped': 0.0125,
#  'slowly': 0.0125,
#  'small': 0.025,
#  'smiled': 0.025,
#  'smiling': 0.025,
#  'snorted': 0.0125,
#  'soft': 0.0125,
#  'sort': 0.0125,
#  'source': 0.0125,
#  'speculation': 0.0125,
#  'splendid': 0.0125,
#  'stained': 0.0125,
#  'stopped': 0.0125,
#  'story': 0.0125,
#  'suddenly': 0.0125,
#  'suit': 0.0125,
#  'swallowing': 0.0125,
#  'table': 0.0125,
#  'talk': 0.0125,
#  'telling': 0.0125,
#  'things': 0.0125,
#  'think': 0.025,
#  'thoroughly': 0.0125,
#  'tightly': 0.0125,
#  'told': 0.0125,
#  'town': 0.0125,
#  'trifle': 0.0125,
#  'upward': 0.0125,
#  'victim': 0.0125,
#  'vigorously': 0.0125,
#  'walls': 0.0125,
#  'want': 0.0125,
#  'wants': 0.0125,
#  'wears': 0.0125,
#  'week': 0.025,
#  'wife': 0.0125,
#  'wine': 0.0625,
#  'winked': 0.0125,
#  'work': 0.0125,
#  'yes': 0.025,
#  'yesterday': 0.0125}

# %%
# Sentence Tokens
sentence_list = [ sentence for sentence in docx.sents ]
# Example of Sentence Tokenization,Word Tokenization and Lowering All Text
# for t in sentence_list:
#     for w in t:
#         print(w.text.lower())
[w.text.lower() for t in sentence_list for w in t ]
# Out:
# ['the',
#  'two',
#  'men',
#  'sat',
#  'across',
#  'from',
#  'each',
#  'other',
#  'in',
#  'soft',
#  'leather',
#  'chairs',
#  '.',
#  'flames',
#  'from',
#  'the',
#  'fireplace',
#  'before',
#  'them',
#  'licked',
#  'upward',
#  'and',
#  'shadows',
#  'danced',
#  'on',
#  'walls',
#  'and',
#  'ceiling',
#  '.',
#  'the',
#  'corners',
#  'were',
#  'in',
#  'complete',
#  'darkness',
#  '.',
#  '\n\n',
#  '"',
#  'i',
#  'say',
#  ',',
#  'george',
#  ',',
#  'this',
#  'wine',
#  'is',
#  'exceedingly',
#  'good',
#  ',',
#  '"',
#  'one',
#  'of',
#  'the',
#  'men',
#  'poured',
#  'rich',
#  'red',
#  'liquid',
#  'from',
#  'a',
#  'large',
#  'decanter',
#  'into',
#  'his',
#  'goblet',
#  '.',
#  '\n\n',
#  '"',
#  'yes',
#  ',',
#  'henry',
#  ',',
#  'it',
#  "'s",
#  'quite',
#  'good',
#  '.',
#  'much',
#  'better',
#  'than',
#  'brandy',
#  ',',
#  '"',
#  'answered',
#  'george',
#  ',',
#  'swallowing',
#  'hard',
#  'and',
#  'rolling',
#  'his',
#  'head',
#  '.',
#  '\n\n',
#  '"',
#  'yes',
#  ',',
#  'yes',
#  ',',
#  '"',
#  'said',
#  'henry',
#  ',',
#  'sighing',
#  'deeply',
#  ',',
#  'his',
#  'lips',
#  'and',
#  'chin',
#  'stained',
#  'from',
#  'the',
#  'beverage',
#  '.',
#  '"',
#  'yes',
#  '.',
#  'yes',
#  '.',
#  'nothing',
#  'like',
#  'good',
#  'wine',
#  '.',
#  'nothing',
#  'like',
#  'it',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'as',
#  'i',
#  'was',
#  'saying',
#  ',',
#  '"',
#  'smiled',
#  'george',
#  '.',
#  '\n\n',
#  '"',
#  'oh',
#  'yes',
#  ',',
#  '"',
#  'henry',
#  'nodded',
#  ',',
#  'setting',
#  'his',
#  'goblet',
#  'on',
#  'the',
#  'table',
#  'and',
#  'leaning',
#  'forward',
#  'in',
#  'his',
#  'seat',
#  '.',
#  '"',
#  'do',
#  'continue',
#  'with',
#  'your',
#  'story',
#  '.',
#  'you',
#  'were',
#  'telling',
#  'me',
#  'about',
#  'how',
#  'you',
#  'met',
#  'the',
#  'devil',
#  'last',
#  'week',
#  ',',
#  'and',
#  'had',
#  'an',
#  'interesting',
#  'chat',
#  'with',
#  'him',
#  '.',
#  '"',
#  'he',
#  'winked',
#  'mischievously',
#  '.',
#  '\n\n',
#  'george',
#  'shook',
#  'his',
#  'head',
#  'vigorously',
#  '.',
#  '"',
#  'and',
#  'i',
#  'most',
#  'certainly',
#  'did',
#  '.',
#  'yes',
#  '.',
#  'met',
#  'the',
#  'devil',
#  'and',
#  'had',
#  'an',
#  'enjoyable',
#  'chat',
#  '.',
#  'he',
#  "'s",
#  'a',
#  'splendid',
#  'chap',
#  ',',
#  'you',
#  'know',
#  '.',
#  'not',
#  'at',
#  'all',
#  'like',
#  'those',
#  'pictures',
#  'you',
#  'see',
#  'of',
#  'him',
#  '.',
#  'no',
#  'horns',
#  'or',
#  'red',
#  'monkey',
#  'outfit',
#  '.',
#  'he',
#  'dresses',
#  'most',
#  'conservatively',
#  ';',
#  'wears',
#  'a',
#  'black',
#  'suit',
#  '.',
#  'and',
#  'he',
#  'has',
#  'nice',
#  'gray',
#  'hair',
#  '.',
#  '"',
#  'george',
#  'patted',
#  'his',
#  'head',
#  '.',
#  '"',
#  'nice',
#  'gray',
#  'hair',
#  '.',
#  '"',
#  '\n\n',
#  'henry',
#  'poured',
#  'himself',
#  'another',
#  'cup',
#  'of',
#  'wine',
#  'and',
#  'sipped',
#  'it',
#  'slowly',
#  '.',
#  '"',
#  'but',
#  'what',
#  'did',
#  'you',
#  'talk',
#  'about',
#  '?',
#  'i',
#  'mean',
#  'you',
#  'have',
#  'nothing',
#  'in',
#  'common',
#  'at',
#  'all',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'oh',
#  'no',
#  '?',
#  '"',
#  'george',
#  'shrugged',
#  '.',
#  '"',
#  'but',
#  'we',
#  'do',
#  '.',
#  'we',
#  'have',
#  'much',
#  'in',
#  'common',
#  '.',
#  'i',
#  'admire',
#  'the',
#  'devil',
#  'and',
#  'told',
#  'him',
#  'so',
#  '.',
#  'and',
#  'he',
#  'said',
#  'that',
#  'he',
#  'would',
#  'be',
#  'glad',
#  'to',
#  'have',
#  'me',
#  'come',
#  'and',
#  'work',
#  'for',
#  'him',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'work',
#  'for',
#  'him',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'yes',
#  '.',
#  'he',
#  'wants',
#  'me',
#  'to',
#  'go',
#  'with',
#  'him',
#  'to',
#  'his',
#  'headquarters',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'but',
#  'his',
#  'headquarters',
#  'are',
#  'in',
#  '...',
#  'a',
#  '...',
#  'well',
#  'you',
#  'know',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'i',
#  'know',
#  ',',
#  'but',
#  'i',
#  'still',
#  'want',
#  'to',
#  'go',
#  '.',
#  'he',
#  'said',
#  'he',
#  'would',
#  'make',
#  'me',
#  'a',
#  'demon',
#  'or',
#  'a',
#  'ghoul',
#  'or',
#  'something',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'horrid',
#  ',',
#  'do',
#  "n't",
#  'you',
#  'think',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'no',
#  ',',
#  'not',
#  'at',
#  'all',
#  '.',
#  '"',
#  'george',
#  'gulped',
#  'down',
#  'the',
#  'last',
#  'of',
#  'his',
#  'wine',
#  '.',
#  '"',
#  'quite',
#  'pleasant',
#  'if',
#  'i',
#  'may',
#  'say',
#  'so',
#  '.',
#  'quite',
#  'a',
#  'change',
#  'from',
#  'the',
#  'market',
#  'and',
#  'speculation',
#  'and',
#  ',',
#  '"',
#  'he',
#  'snorted',
#  'loudly',
#  ',',
#  '"',
#  'those',
#  'damn',
#  'commodities',
#  'that',
#  'i',
#  'lost',
#  'so',
#  'heavily',
#  'on',
#  'yesterday',
#  '.',
#  'no',
#  ',',
#  'i',
#  'think',
#  'i',
#  "'d",
#  'enjoy',
#  'seeing',
#  'things',
#  'as',
#  'a',
#  'demon',
#  'or',
#  'a',
#  'ghoul',
#  'or',
#  'something',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'what',
#  'do',
#  'you',
#  'see',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'oh',
#  'you',
#  'know',
#  '.',
#  'graveyards',
#  ',',
#  'coffins',
#  'and',
#  'corpses',
#  '....',
#  '"',
#  '\n\n',
#  'henry',
#  'laughed',
#  '.',
#  '"',
#  'oh',
#  ',',
#  'that',
#  "'s",
#  'amusing',
#  '.',
#  'most',
#  'amusing',
#  '.',
#  '"',
#  '\n\n',
#  'george',
#  'smiled',
#  'tightly',
#  '.',
#  '"',
#  'and',
#  'you',
#  'see',
#  'the',
#  'dead',
#  'in',
#  'hell',
#  ',',
#  'the',
#  'fire',
#  'and',
#  'brimstone',
#  ',',
#  'and',
#  'you',
#  'hear',
#  'their',
#  'cries',
#  'of',
#  'anguish',
#  'and',
#  'it',
#  "'s",
#  'quite',
#  'pleasant',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'then',
#  'why',
#  'do',
#  "n't",
#  'you',
#  'go',
#  'with',
#  'the',
#  'devil',
#  'and',
#  'be',
#  'done',
#  'with',
#  'it',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'but',
#  'i',
#  'am',
#  'going',
#  'to',
#  'go',
#  ',',
#  'henry',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'then',
#  'go',
#  '!',
#  '"',
#  '\n\n',
#  '"',
#  'but',
#  'i',
#  'must',
#  'do',
#  'something',
#  'first',
#  '.',
#  'it',
#  "'s",
#  'a',
#  'sort',
#  'of',
#  'qualification',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'yes',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'i',
#  'must',
#  'kill',
#  'someone',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'but',
#  'that',
#  "'s",
#  'most',
#  'naughty',
#  ',',
#  'old',
#  'boy',
#  ',',
#  'is',
#  "n't",
#  'it',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'not',
#  'when',
#  'you',
#  'have',
#  'a',
#  'good',
#  'reason',
#  '.',
#  '"',
#  '\n\n',
#  'henry',
#  'held',
#  'up',
#  'the',
#  'decanter',
#  'and',
#  'looked',
#  'at',
#  'the',
#  'small',
#  'amount',
#  'of',
#  'wine',
#  'that',
#  'was',
#  'left',
#  '.',
#  'he',
#  'shook',
#  'his',
#  'head',
#  'sadly',
#  '.',
#  '"',
#  'but',
#  'who',
#  "'s",
#  'going',
#  'to',
#  'be',
#  'your',
#  'victim',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'you',
#  ',',
#  '"',
#  'answered',
#  'george',
#  '.',
#  '\n\n',
#  '"',
#  'me',
#  '?',
#  '"',
#  'said',
#  'henry',
#  ',',
#  'smiling',
#  '.',
#  '\n\n',
#  '"',
#  'yes',
#  ',',
#  'you',
#  '.',
#  '"',
#  '\n\n',
#  '"',
#  'are',
#  'you',
#  'mad',
#  '?',
#  '"',
#  '\n\n',
#  '"',
#  'no',
#  '.',
#  '"',
#  '\n\n',
#  'henry',
#  'stopped',
#  'smiling',
#  'and',
#  'his',
#  'face',
#  'grew',
#  'a',
#  'trifle',
#  'pale',
#  '.',
#  'he',
#  'suddenly',
#  'had',
#  'the',
#  'sickening',
#  'feeling',
#  'that',
#  'george',
#  'was',
#  "n't",
#  'kidding',
#  'him',
#  'any',
#  'more',
#  '.',
#  '"',
#  'but',
#  'why',
#  'me',
#  '?',
#  '"',
#  '\n\n',
#  'george',
#  'pulled',
#  'a',
#  'small',
#  'revolver',
#  'from',
#  'his',
#  'breast',
#  'pocket',
#  '.',
#  '"',
#  'i',
#  'have',
#  'it',
#  'from',
#  'what',
#  'i',
#  'believe',
#  'to',
#  'be',
#  'a',
#  'thoroughly',
#  'reliable',
#  'source',
#  'that',
#  'while',
#  'i',
#  'was',
#  'out',
#  'of',
#  'town',
#  'last',
#  'week',
#  'you',
#  'were',
#  'out',
#  'with',
#  'my',
#  'wife',
#  '.',
#  '"']

# %%
sentence_scores = {}  
for sent in sentence_list:  
        for word in sent:
            if word.text.lower() in word_frequencies.keys():
                if len(sent.text.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        sentence_scores[sent] = word_frequencies[word.text.lower()]
                    else:
                        sentence_scores[sent] += word_frequencies[word.text.lower()]

# %%
# Sentence Score via comparrng each word with sentence
# Alternative Method
lowered_sentence_list = [w.text.lower() for t in sentence_list for w in t ]
lowered_sentence_scores = {}  
for sent in lowered_sentence_list:  
        for word in sent:
           if word.text in word_frequencies.keys():
                if len(sent.split(' ')) < 30:
                    if sent not in sentence_scores.keys():
                        lowered_sentence_scores[sent] = word_frequencies[word.text]
                    else:
                        lowered_sentence_scores[sent] += word_frequencies[word.text]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-021fb28da3c2> in <module>()
#       5 for sent in lowered_sentence_list:
#       6         for word in sent:
# ----> 7            if word.text.lower() in word_frequencies.keys():
#       8                 if len(sent.split(' ')) < 30:
#       9                     if sent not in sentence_scores.keys():
#
# AttributeError: 'str' object has no attribute 'text'

# %%
sentence_scores
# Out:
# {The two men sat across from each other in soft leather chairs.: 0.8875,
#  Flames from the fireplace before them licked upward and shadows danced on walls and ceiling.: 0.9,
#  The corners were in complete darkness.
#  : 1.275,
#  "I say, George, this wine is exceedingly good," one of the men poured rich red liquid from a large decanter into his goblet.
#  : 4.725,
#  "Yes, Henry, it's quite good.: 2.6875,
#  Much better than brandy," answered George, swallowing hard and rolling his head.
#  : 3.175,
#  "Yes, yes," said Henry, sighing deeply, his lips and chin stained from the beverage.: 4.5875,
#  ": 1.0,
#  Yes.: 0.8375,
#  Yes.: 0.8375,
#  Nothing like good wine.: 0.9625,
#  Nothing like it."
#  : 2.275,
#  "As I was saying," smiled George.
#  : 3.675,
#  "Oh yes," Henry nodded, setting his goblet on the table and leaning forward in his seat. ": 4.737500000000001,
#  Do continue with your story.: 0.8375,
#  You were telling me about how you met the Devil last week, and had an interesting chat with him.": 2.3,
#  He winked mischievously.
#  : 1.2625,
#  George shook his head vigorously. ": 1.9,
#  And I most certainly did.: 0.825,
#  Yes.: 0.8375,
#  Met the Devil and had an enjoyable chat.: 0.8625,
#  He's a splendid chap, you know.: 1.2875,
#  Not at all like those pictures you see of him.: 0.8625,
#  No horns or red monkey outfit.: 0.875,
#  He dresses most conservatively; wears a black suit.: 0.8875,
#  And he has nice gray hair.": 1.875,
#  George patted his head.: 0.875,
#  "Nice gray hair."
#  : 3.3,
#  Henry poured himself another cup of wine and sipped it slowly. ": 1.9375,
#  But what did you talk about?: 0.1625,
#  I mean you have nothing in common at all."
#  : 2.275,
#  ": 1.0,
#  Oh no?": 1.15,
#  George shrugged. ": 1.825,
#  But we do.: 0.8125,
#  We have much in common.: 0.8375,
#  I admire the Devil and told him so.: 0.8375,
#  And he said that he would be glad to have me come and work for him."
#  : 2.3249999999999997,
#  "Work for him?"
#  : 2.5874999999999995,
#  ": 1.0,
#  Yes.: 0.8375,
#  He wants me to go with him to his headquarters."
#  : 2.275,
#  "But his headquarters are in ...: 1.0499999999999998,
#  a ...: 0.025,
#  well you know.: 0.8625,
#  "
#  : 1.425,
#  "I know, but I still want to go.: 2.2750000000000004,
#  He said he would make me a demon or a ghoul or something."
#  : 2.3375,
#  "Horrid, don't you think?"
#  : 2.9999999999999996,
#  "No, not at all.": 3.2125,
#  George gulped down the last of his wine. ": 1.8875,
#  Quite pleasant if I may say so.: 0.8375,
#  Quite a change from the market and speculation and," he snorted loudly, "those damn commodities that I lost so heavily on yesterday.: 3.7375000000000007,
#  No, I think I'd enjoy seeing things as a demon or a ghoul or something."
#  : 2.75,
#  "What do you see?"
#  : 2.5749999999999997,
#  "Oh you know.: 1.8625,
#  Graveyards, coffins and corpses....: 0.43750000000000006,
#  "
#  : 1.425,
#  Henry laughed.: 0.825,
#  "Oh, that's amusing.: 2.2375,
#  Most amusing."
#  : 2.2624999999999997,
#  George smiled tightly. ": 1.85,
#  And you see the dead in Hell, the fire and brimstone, and you hear their cries of anguish: 0.875,
#  and it's quite pleasant.: 0.8375,
#  "
#  : 1.425,
#  "Then why don't you go with the Devil and be done with it?"
#  : 2.5749999999999997,
#  "But I am going to go, Henry."
#  : 3.6624999999999996,
#  "Then go!"
#  : 2.4375,
#  "But I must do something first.: 1.8125,
#  It's a sort of qualification."
#  : 2.2624999999999997,
#  "Yes?"
#  : 2.5999999999999996,
#  "I must kill someone."
#  : 3.25,
#  "But that's most naughty, old boy, isn't it?"
#  : 3.4124999999999996,
#  "Not when you have a good reason.: 1.875,
#  "
#  : 1.425,
#  Henry held up the decanter and looked at the small amount of wine that was left.: 0.9625,
#  He shook his head sadly. ": 1.9,
#  But who's going to be your victim?"
#  : 1.6125,
#  "You," answered George.
#  : 3.6624999999999996,
#  "Me?" said Henry, smiling.
#  : 3.8624999999999994,
#  ": 1.0,
#  Yes, you."
#  : 2.6624999999999996,
#  "Are you mad?"
#  : 2.5874999999999995,
#  "No."
#  : 3.2375,
#  Henry stopped smiling and his face grew a trifle pale.: 0.9,
#  He suddenly had the sickening feeling that George wasn't kidding him any more. ": 1.8625,
#  But why me?"
#  : 1.575,
#  George pulled a small revolver from his breast pocket.: 0.8875,
#  "I have it from what I believe to be a thoroughly reliable source that while I was out of town last week you were out with my wife.": 2.9124999999999996}

# %%
# Import Heapq 
from heapq import nlargest
summarized_sentences = nlargest(7, sentence_scores, key=sentence_scores.get)
summarized_sentences
# Out:
# ["Oh yes," Henry nodded, setting his goblet on the table and leaning forward in his seat. ",
#  "I say, George, this wine is exceedingly good," one of the men poured rich red liquid from a large decanter into his goblet.
#  ,
#  "Yes, yes," said Henry, sighing deeply, his lips and chin stained from the beverage.,
#  "Me?" said Henry, smiling.
#  ,
#  Quite a change from the market and speculation and," he snorted loudly, "those damn commodities that I lost so heavily on yesterday.,
#  "As I was saying," smiled George.
#  ,
#  "But I am going to go, Henry."
#  ]

# %%
# Convert Sentences from Spacy Span to Strings for joining entire sentence
for w in summarized_sentences:
    print(w.text)
# List Comprehension of Sentences Converted From Spacy.span to strings
final_sentences = [ w.text for w in summarized_sentences ]

summary = ' '.join(final_sentences)
summary
# Out:
# "Oh yes," Henry nodded, setting his goblet on the table and leaning forward in his seat. "
# "I say, George, this wine is exceedingly good," one of the men poured rich red liquid from a large decanter into his goblet.
#
#
# "Yes, yes," said Henry, sighing deeply, his lips and chin stained from the beverage.
# "Me?" said Henry, smiling.
#
#
# Quite a change from the market and speculation and," he snorted loudly, "those damn commodities that I lost so heavily on yesterday.
# "As I was saying," smiled George.
#
#
# "But I am going to go, Henry."
# '"Oh yes," Henry nodded, setting his goblet on the table and leaning forward in his seat. " "I say, George, this wine is exceedingly good," one of the men poured rich red liquid from a large decanter into his goblet.\n\n "Yes, yes," said Henry, sighing deeply, his lips and chin stained from the beverage. "Me?" said Henry, smiling.\n\n Quite a change from the market and speculation and," he snorted loudly, "those damn commodities that I lost so heavily on yesterday. "As I was saying," smiled George.\n\n "But I am going to go, Henry."\n\n'

# %%
len(document1)
# Out:
# 3163

# %%
len(summary)
# Out:
# 533
